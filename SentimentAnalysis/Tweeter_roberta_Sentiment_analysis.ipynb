# %%
# %pip install -r "../requirements.txt"
# Out:
# Requirement already satisfied: colorama==0.4.6 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from -r ../requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: Crawl4AI==0.4.248 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from -r ../requirements.txt (line 2)) (0.4.248)
# Requirement already satisfied: pandas==2.2.3 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from -r ../requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: urllib3~=2.4.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from -r ../requirements.txt (line 4)) (2.4.0)
# Requirement already satisfied: transformers in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from -r ../requirements.txt (line 5)) (4.51.3)
# Requirement already satisfied: langchain in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from -r ../requirements.txt (line 6)) (0.3.23)
# Requirement already satisfied: langchain-huggingface in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from -r ../requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: peft in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from -r ../requirements.txt (line 8)) (0.5.0)
# Requirement already satisfied: torch in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from -r ../requirements.txt (line 9)) (2.0.1)
# Requirement already satisfied: accelerate in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from -r ../requirements.txt (line 10)) (0.23.0)
# Requirement already satisfied: aiosqlite~=0.20 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (0.21.0)
# Requirement already satisfied: lxml~=5.3 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (5.3.2)
# Requirement already satisfied: litellm>=1.53.1 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.65.8)
# Requirement already satisfied: numpy<3,>=1.26.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.26.0)
# Requirement already satisfied: pillow~=10.4 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (10.4.0)
# Requirement already satisfied: playwright>=1.49.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.51.0)
# Requirement already satisfied: python-dotenv~=1.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: requests~=2.26 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: beautifulsoup4~=4.12 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: tf-playwright-stealth>=1.1.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.1.2)
# Requirement already satisfied: xxhash~=3.4 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: rank-bm25~=0.2 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (24.1.0)
# Requirement already satisfied: snowballstemmer~=2.2 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: pydantic>=2.10 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (2.11.3)
# Requirement already satisfied: pyOpenSSL>=24.3.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (25.0.0)
# Requirement already satisfied: psutil>=6.1.1 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (7.0.0)
# Requirement already satisfied: nltk>=3.9.1 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (3.9.1)
# Requirement already satisfied: rich>=13.9.4 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (14.0.0)
# Requirement already satisfied: cssselect>=1.2.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: httpx==0.27.2 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (0.27.2)
# Requirement already satisfied: fake-useragent>=2.0.3 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from pandas==2.2.3->-r ../requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from pandas==2.2.3->-r ../requirements.txt (line 3)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from pandas==2.2.3->-r ../requirements.txt (line 3)) (2023.3)
# Requirement already satisfied: anyio in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from httpx==0.27.2->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: certifi in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from httpx==0.27.2->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from httpx==0.27.2->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.0.8)
# Requirement already satisfied: idna in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from httpx==0.27.2->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (3.4)
# Requirement already satisfied: sniffio in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from httpx==0.27.2->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from httpcore==1.*->httpx==0.27.2->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: filelock in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from transformers->-r ../requirements.txt (line 5)) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from transformers->-r ../requirements.txt (line 5)) (0.30.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from transformers->-r ../requirements.txt (line 5)) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from transformers->-r ../requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from transformers->-r ../requirements.txt (line 5)) (2023.10.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from transformers->-r ../requirements.txt (line 5)) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from transformers->-r ../requirements.txt (line 5)) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from transformers->-r ../requirements.txt (line 5)) (4.66.1)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.51 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from langchain->-r ../requirements.txt (line 6)) (0.3.52)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from langchain->-r ../requirements.txt (line 6)) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from langchain->-r ../requirements.txt (line 6)) (0.3.31)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from langchain->-r ../requirements.txt (line 6)) (2.0.40)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from langchain->-r ../requirements.txt (line 6)) (4.0.3)
# Requirement already satisfied: sentence-transformers>=2.6.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from langchain-huggingface->-r ../requirements.txt (line 7)) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from torch->-r ../requirements.txt (line 9)) (4.13.2)
# Requirement already satisfied: sympy in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from torch->-r ../requirements.txt (line 9)) (1.12)
# Requirement already satisfied: networkx in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from torch->-r ../requirements.txt (line 9)) (3.1)
# Requirement already satisfied: jinja2 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from torch->-r ../requirements.txt (line 9)) (3.1.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from beautifulsoup4~=4.12->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (2.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers->-r ../requirements.txt (line 5)) (2023.6.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain->-r ../requirements.txt (line 6)) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.51->langchain->-r ../requirements.txt (line 6)) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain->-r ../requirements.txt (line 6)) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain->-r ../requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain->-r ../requirements.txt (line 6)) (0.23.0)
# Requirement already satisfied: aiohttp in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (3.8.5)
# Requirement already satisfied: click in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (8.1.8)
# Requirement already satisfied: importlib-metadata>=6.8.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (8.6.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (4.23.0)
# Requirement already satisfied: openai>=1.68.2 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.74.0)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from jinja2->torch->-r ../requirements.txt (line 9)) (2.1.3)
# Requirement already satisfied: joblib in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from nltk>=3.9.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: pyee<13,>=12 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from playwright>=1.49.0->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (12.1.1)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from playwright>=1.49.0->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from pydantic>=2.10->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from pydantic>=2.10->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from pydantic>=2.10->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: cryptography<45,>=41.0.5 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from pyOpenSSL>=24.3.0->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (44.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->-r ../requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from requests~=2.26->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from rich>=13.9.4->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from rich>=13.9.4->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (2.16.1)
# Requirement already satisfied: scikit-learn in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface->-r ../requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: scipy in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface->-r ../requirements.txt (line 7)) (1.11.3)
# Requirement already satisfied: fake-http-header<0.4.0,>=0.3.5 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from tf-playwright-stealth>=1.1.0->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (0.3.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from sympy->torch->-r ../requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from cryptography<45,>=41.0.5->pyOpenSSL>=24.3.0->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from importlib-metadata>=6.8.0->litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (3.21.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.51->langchain->-r ../requirements.txt (line 6)) (2.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (0.10.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from openai>=1.68.2->litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from openai>=1.68.2->litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from anyio->httpx==0.27.2->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from aiohttp->litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from aiohttp->litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from aiohttp->litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from aiohttp->litellm>=1.53.1->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface->-r ../requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: pycparser in c:\users\arijit\desktop\final-year-project\.venv\lib\site-packages (from cffi>=1.12->cryptography<45,>=41.0.5->pyOpenSSL>=24.3.0->Crawl4AI==0.4.248->-r ../requirements.txt (line 2)) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading https://download.pytorch.org/whl/cu126/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 38.0 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 25.1 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.0 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu126/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.3 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu126/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu126/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 39.0 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !sudo nvidia-smi --gpu-reset -i 0
# !nvidia-smi
# Out:
# NVIDIA-SMI couldn't find libnvidia-ml.so library in your system. Please make sure that the NVIDIA Display Driver is properly installed and present in your system.
# Please also try adding directory that contains libnvidia-ml.so to your system PATH.
# Thu Apr 17 16:58:14 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch

torch.cuda.reset_max_memory_allocated()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/cuda/memory.py:391: FutureWarning: torch.cuda.reset_max_memory_allocated now calls torch.cuda.reset_peak_memory_stats, which resets /all/ peak memory stats.
#   warnings.warn(

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !pip install transformers==4.40.1 peft==0.4.0
# !pip install sentencepiece
# !pip install accelerate
# !pip install torch
# !pip install peft
# !pip install datasets
# !pip install bitsandbytes
# !pip install numpy pandas scipy
# Out:
# Collecting transformers==4.40.1
#   Downloading transformers-4.40.1-py3-none-any.whl.metadata (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 6.8 MB/s eta 0:00:00
# Collecting peft==0.4.0
#   Downloading peft-0.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.1) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.1) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.1) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.1) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.1) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.1) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.1) (2.32.3)
# Collecting tokenizers<0.20,>=0.19 (from transformers==4.40.1)
#   Downloading tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.1) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.1) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft==0.4.0) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.4.0) (2.6.0+cu124)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (from peft==0.4.0) (1.5.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.40.1) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.40.1) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft==0.4.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft==0.4.0) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.40.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.40.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.40.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.40.1) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->peft==0.4.0) (3.0.2)
# Downloading transformers-4.40.1-py3-none-any.whl (9.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 46.3 MB/s eta 0:00:00
# Downloading peft-0.4.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 7.6 MB/s eta 0:00:00
# Downloading tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 22.9 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers, peft
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.1
#     Uninstalling transformers-4.51.1:
#       Successfully uninstalled transformers-4.51.1
#   Attempting uninstall: peft
#     Found existing installation: peft 0.14.0
#     Uninstalling peft-0.14.0:
#       Successfully uninstalled peft-0.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.40.1 which is incompatible.
# Successfully installed peft-0.4.0 tokenizers-0.19.1 transformers-4.40.1
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.5.2)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.30.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2025.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.1.31)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from peft) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from peft) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from peft) (2.6.0+cu124)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from peft) (4.40.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (from peft) (1.5.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate->peft) (0.30.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->peft) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers->peft) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.11/dist-packages (from transformers->peft) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers->peft) (4.67.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->peft) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->peft) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->peft) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->peft) (2025.1.31)
# Collecting datasets
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.19.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 13.7 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.1 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 19.0 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 14.4 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 20.2 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed datasets-3.5.0 dill-0.3.8 fsspec-2024.12.0 multiprocess-0.70.16 xxhash-3.5.0
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 10.4 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.5
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# %pip install dotenv
# %pip install accelerate
# Out:
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Collecting python-dotenv (from dotenv)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, dotenv
# Successfully installed dotenv-0.9.9 python-dotenv-1.1.0
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.5.2)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.30.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2024.12.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.1.31)

# %% [markdown]
# # Tweeter Roberta Sentiment Analysis

# %%
import torch
torch.cuda.empty_cache()

# %%
import torch, gc
gc.collect()
torch.cuda.empty_cache()

# %%
import torch
import gc

def print_gpu_memory():
    allocated = torch.cuda.memory_allocated() / (1024**2)
    cached = torch.cuda.memory_reserved() / (1024**2)
    print(f"Allocated: {allocated:.2f} MB")
    print(f"Cached: {cached:.2f} MB")

# Before clearing the cache
print("Before clearing cache:")
print_gpu_memory()

# Clearing cache
gc.collect()
torch.cuda.empty_cache()

# After clearing the cache
print("\nAfter clearing cache:")
print_gpu_memory()
# Out:
# Before clearing cache:
# Allocated: 0.00 MB
# Cached: 0.00 MB
#
# After clearing cache:
# Allocated: 0.00 MB
# Cached: 0.00 MB

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer, AutoConfig
import numpy as np
from scipy.special import softmax
# Preprocess text (username and link placeholders)
def preprocess(text):
    new_text = []
    for t in text.split(" "):
        t = '@user' if t.startswith('@') and len(t) > 1 else t
        t = 'http' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment-latest"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
config = AutoConfig.from_pretrained(MODEL)
# PT
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
#model.save_pretrained(MODEL)
text = "Covid cases are increasing fast!"
text = preprocess(text)
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
# # TF
# model = TFAutoModelForSequenceClassification.from_pretrained(MODEL)
# model.save_pretrained(MODEL)
# text = "Covid cases are increasing fast!"
# encoded_input = tokenizer(text, return_tensors='tf')
# output = model(encoded_input)
# scores = output[0][0].numpy()
# scores = softmax(scores)
# Print labels and scores
ranking = np.argsort(scores)
ranking = ranking[::-1]
for i in range(scores.shape[0]):
    l = config.id2label[ranking[i]]
    s = scores[ranking[i]]
    print(f"{i+1}) {l} {np.round(float(s), 4)}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 1) negative 0.7236
# 2) neutral 0.2287
# 3) positive 0.0477

# %%
# !pip install colorama
# Out:
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %%
from concurrent.futures import ThreadPoolExecutor
from colorama import Fore, Style, init
import pandas as pd
import os
import time
import warnings
from transformers import pipeline

# %%
init(autoreset=True)

# %%
def load_model(model):
    return AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
def preprocess(text):
    new_text = []
    for t in text.split(" "):
        t = '@user' if t.startswith('@') and len(t) > 1 else t
        t = 'http' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)

# %%
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer, AutoConfig
import numpy as np
from scipy.special import softmax

MODEL = f"cardiffnlp/twitter-roberta-base-sentiment-latest"

tokenizer = AutoTokenizer.from_pretrained(MODEL)
config = AutoConfig.from_pretrained(MODEL)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# Global Constants
INPUT_FILE = "/content/data.csv"
OUTPUT_FILE = "/content/tweeter_roberta_sentiment_analysis_data.csv"
NUM_PROCESSES = min(4, os.cpu_count() - 1)

sentiment_model = load_model(MODEL)

def find_sentiment(text):
  # try:
  #   print(f"{Fore.GREEN} Input:- {text[:20]}{Style.RESET_ALL}")
  #   result = sentiment_model(text)
  #   print(f"{Fore.GREEN} Output:- {result}{Style.RESET_ALL}")
  #   return list((text, result[0]["label"], result[0]["score"]))
  # except Exception as e:
  #   print(f"{Fore.RED} Error: {e}{Style.RESET_ALL}")
  #   return list((text, np.nan, np.nan))

  try:
    text = preprocess(text)
    encoded_input = tokenizer(text, return_tensors='pt')
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)

    # sort the ranks
    ranking = np.argsort(scores)
    ranking = ranking[::-1]

    label = config.id2label[ranking[0]]
    sentiment_score = scores[ranking[0]]

    print(f"{Fore.GREEN} Input:- {text[:20]}{Style.RESET_ALL}")

    print(f"{Fore.GREEN} Output:- label = {label}, sentiment_score = {sentiment_score} {Style.RESET_ALL}")

    return list((text, label, sentiment_score))

    # for i in range(scores.shape[0]):
    #     l = config.id2label[ranking[i]]
    #     s = scores[ranking[i]]
    #     print(f"{i+1}) {l} {np.round(float(s), 4)}")
  except Exception as e:
    print(f"{Fore.RED} Error: {e}{Style.RESET_ALL}")
    return list((text, np.nan, np.nan))



def process_texts_in_parallel(texts):
    """
        process sentiment from the texts in paprallel
    """
    print(f"{Fore.CYAN}🔹 Using {NUM_PROCESSES} parallel threads...{Style.RESET_ALL}")

    with ThreadPoolExecutor(NUM_PROCESSES) as executor:
        results = list(executor.map(find_sentiment, texts))

    return results


def sentiment_analysis_of_text_data():
    if not os.path.exists(INPUT_FILE):
        print(f"{Fore.RED}Error: '{INPUT_FILE}' not found!{Style.RESET_ALL}")
        return

    df = pd.read_csv(INPUT_FILE)

    if "News" not in df.columns:
        print(f"{Fore.RED}Error: 'News' column missing in CSV!{Style.RESET_ALL}")
        return

    texts = df["News"].dropna().tolist()

    # when the scrapping stops unexpectedly
    already_processed_texts = set()
    if os.path.exists(OUTPUT_FILE):
        already_processed_texts = set(
            pd.read_csv(OUTPUT_FILE)["News"].dropna().tolist()
        )

    # filter the links if they are already processed

    links = [text for text in texts if text not in already_processed_texts]

    # Split into batches to avoid excessive memory usage
    batch_size = 500
    total_batches = (len(texts) // batch_size) + 1

    all_results = []

    for i in range(total_batches):
        batch_texts = texts[i * batch_size: (i + 1) * batch_size]
        print(f"{Fore.YELLOW} Processing batch {i + 1}/{total_batches} ({len(batch_texts)} links){Style.RESET_ALL}")

        results = process_texts_in_parallel(batch_texts)  # Removed `[0]`
        all_results.extend(results)

        # Save intermediate results
        temp_df = pd.DataFrame(all_results, columns=["News", "sentiment_label", "sentiment_score"])
        temp_df.to_csv(OUTPUT_FILE, index=False, encoding="utf-8")

    print(f"{Fore.GREEN}✔️ Sentiment Analysis complete! Data saved to '{OUTPUT_FILE}'{Style.RESET_ALL}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
if __name__ == "__main__":
   sentiment_analysis_of_text_data()
# Out:
#  Processing batch 1/553 (500 links)
# 🔹 Using 1 parallel threads...
#  Input:- disney marathon how
#  Output:- label = neutral, sentiment_score = 0.8928703665733337
#  Input:- bharti airtel servic
#  Output:- label = neutral, sentiment_score = 0.9084096550941467
#  Input:- fallout 76 nuke code
#  Output:- label = neutral, sentiment_score = 0.9217000603675842
#  Input:- is retirement on you
#  Output:- label = neutral, sentiment_score = 0.8655651211738586
#  Input:- raise a glass to gif
#  Output:- label = positive, sentiment_score = 0.6357289552688599
#  Input:- when psus start to f
#  Output:- label = neutral, sentiment_score = 0.7598106861114502
#  Input:- india infrantic the
#  Output:- label = neutral, sentiment_score = 0.5356217622756958
#  Input:- listening to imagine
#  Output:- label = neutral, sentiment_score = 0.8125232458114624
#  Input:- demonstrating democr
#  Output:- label = positive, sentiment_score = 0.641991913318634
#  Input:- two fresh covid case
#  Output:- label = neutral, sentiment_score = 0.5094090700149536
#  Input:- manipur four people
#  Output:- label = negative, sentiment_score = 0.6816207766532898
#  Input:- isis module case 6 a
#  Output:- label = negative, sentiment_score = 0.6221405863761902
#  Input:- india inc welcomes 2
#  Output:- label = positive, sentiment_score = 0.8483210206031799
#  Input:- david beckham mocks
#  Output:- label = negative, sentiment_score = 0.585963249206543
#  Input:- assam cm sarma rules
#  Output:- label = neutral, sentiment_score = 0.7210994362831116
#  Input:- pathaan star john ab
#  Output:- label = neutral, sentiment_score = 0.8985995054244995
#  Input:- 151 myanmar soldiers
#  Output:- label = neutral, sentiment_score = 0.8584634065628052
#  Input:- meditate be empowere
#  Output:- label = neutral, sentiment_score = 0.5194623470306396
#  Input:- india vs south afric
#  Output:- label = neutral, sentiment_score = 0.8451798558235168
#  Input:- unlocking the secret
#  Output:- label = neutral, sentiment_score = 0.8322365283966064
#  Input:- terrorised by hny te
#  Output:- label = negative, sentiment_score = 0.7171235680580139
#  Input:- god of war ragnarok
#  Output:- label = neutral, sentiment_score = 0.8612852096557617
#  Input:- who was benjamin kip
#  Output:- label = negative, sentiment_score = 0.666641354560852
#  Input:- ahead of market 10 t
#  Output:- label = neutral, sentiment_score = 0.9239722490310669
#  Input:- indias mineral outpu
#  Output:- label = positive, sentiment_score = 0.5043699741363525
#  Input:- air india derosters
#  Output:- label = negative, sentiment_score = 0.4968215227127075
#  Input:- australian olympic c
#  Output:- label = negative, sentiment_score = 0.5348228216171265
#  Input:- monster hunter nows
#  Output:- label = positive, sentiment_score = 0.9250309467315674
#  Input:- donny van de beek co
#  Output:- label = neutral, sentiment_score = 0.8775796890258789
#  Input:- vodafone idea shares
#  Output:- label = positive, sentiment_score = 0.7046551704406738
#  Input:- netflixs wednesday s
#  Output:- label = positive, sentiment_score = 0.7259697318077087
#  Input:- sjvn gets govt appro
#  Output:- label = neutral, sentiment_score = 0.7748045325279236
#  Input:- gurugram reports fir
#  Output:- label = negative, sentiment_score = 0.7811821103096008
#  Input:- petition filed in sc
#  Output:- label = negative, sentiment_score = 0.4942277669906616
#  Input:- karnataka state owne
#  Output:- label = neutral, sentiment_score = 0.546803891658783
#  Input:- planning to lose wei
#  Output:- label = neutral, sentiment_score = 0.8218367695808411
#  Input:- private madrassas in
#  Output:- label = neutral, sentiment_score = 0.7357733845710754
#  Input:- corruption is the di
#  Output:- label = negative, sentiment_score = 0.8935815691947937
#  Input:- prabhas thanks fans
#  Output:- label = positive, sentiment_score = 0.9682921171188354
#  Input:- lic gets rs 806 cror
#  Output:- label = neutral, sentiment_score = 0.8662614226341248
#  Input:- certainly very impor
#  Output:- label = positive, sentiment_score = 0.6111953258514404
#  Input:- past lives streaming
#  Output:- label = neutral, sentiment_score = 0.9540672898292542
#  Input:- maharashtra labour d
#  Output:- label = neutral, sentiment_score = 0.6498779058456421
#  Input:- manipur major search
#  Output:- label = neutral, sentiment_score = 0.8458324670791626
#  Input:- senior national wres
#  Output:- label = neutral, sentiment_score = 0.9291688799858093
#  Input:- outgoing chief secre
#  Output:- label = neutral, sentiment_score = 0.9177170395851135
#  Input:- navigating the trade
#  Output:- label = neutral, sentiment_score = 0.7582448124885559
#  Input:- dgca issues 1622 com
#  Output:- label = neutral, sentiment_score = 0.8595772981643677
#  Input:- successfully met thi
#  Output:- label = positive, sentiment_score = 0.666566014289856
#  Input:- paula abdul sues ame
#  Output:- label = negative, sentiment_score = 0.7242084741592407
#  Input:- assam cm says tata e
#  Output:- label = neutral, sentiment_score = 0.8626484870910645
#  Input:- eicher motors gets r
#  Output:- label = neutral, sentiment_score = 0.7433329224586487
#  Input:- ketone supplements m
#  Output:- label = neutral, sentiment_score = 0.7462509870529175
#  Input:- isro launches indias
#  Output:- label = neutral, sentiment_score = 0.6510383486747742
#  Input:- global upheaval mark
#  Output:- label = negative, sentiment_score = 0.8009277582168579
#  Input:- rbi simplifies react
#  Output:- label = neutral, sentiment_score = 0.7195059061050415
#  Input:- 10 best samsung refr
#  Output:- label = positive, sentiment_score = 0.9456457495689392
#  Input:- survivor star parvat
#  Output:- label = neutral, sentiment_score = 0.8917829394340515
#  Input:- diffusion engineers
#  Output:- label = neutral, sentiment_score = 0.9200590252876282
#  Input:- hsbc mf cautions aga
#  Output:- label = neutral, sentiment_score = 0.7002301216125488
#  Input:- 97 38 percent of rs
#  Output:- label = neutral, sentiment_score = 0.8579828143119812
#  Input:- sale of 30th tranche
#  Output:- label = neutral, sentiment_score = 0.9395937919616699
#  Input:- ultratech cement sla
#  Output:- label = neutral, sentiment_score = 0.6478033661842346
#  Input:- nobel laureate dr mu
#  Output:- label = neutral, sentiment_score = 0.63676917552948
#  Input:- heres why bill clint
#  Output:- label = neutral, sentiment_score = 0.6364918947219849
#  Input:- govt extends tenure
#  Output:- label = neutral, sentiment_score = 0.8587297201156616
#  Input:- amid covid surge leh
#  Output:- label = neutral, sentiment_score = 0.8204990029335022
#  Input:- imd forecasts coldwa
#  Output:- label = neutral, sentiment_score = 0.8756536841392517
#  Input:- indias economy burns
#  Output:- label = neutral, sentiment_score = 0.6316344141960144
#  Input:- stage iii of grap an
#  Output:- label = neutral, sentiment_score = 0.7713777422904968
#  Input:- texmaco appoints sud
#  Output:- label = neutral, sentiment_score = 0.8962830305099487
#  Input:- anticipating springs
#  Output:- label = positive, sentiment_score = 0.8772492408752441
#  Input:- they dont care ex au
#  Output:- label = negative, sentiment_score = 0.7175118327140808
#  Input:- cji refuses to respo
#  Output:- label = negative, sentiment_score = 0.6950415968894958
#  Input:- fire country season
#  Output:- label = neutral, sentiment_score = 0.8451659083366394
#  Input:- we do not recognise
#  Output:- label = negative, sentiment_score = 0.7179045081138611
#  Input:- centre extends auto
#  Output:- label = neutral, sentiment_score = 0.8362915515899658
#  Input:- tvs motor company po
#  Output:- label = neutral, sentiment_score = 0.5971449613571167
#  Input:- milestone unlocked a
#  Output:- label = neutral, sentiment_score = 0.5760995149612427
#  Input:- taylor swift joins c
#  Output:- label = positive, sentiment_score = 0.5894774198532104
#  Input:- dot readying over 30
#  Output:- label = neutral, sentiment_score = 0.8991034030914307
#  Input:- ayodhya case judges
#  Output:- label = neutral, sentiment_score = 0.8414062261581421
#  Input:- as india gallops so
#  Output:- label = neutral, sentiment_score = 0.8851260542869568
#  Input:- anand mahindras new
#  Output:- label = positive, sentiment_score = 0.7170389294624329
#  Input:- sia stuns at kardash
#  Output:- label = positive, sentiment_score = 0.6442707777023315
#  Input:- conor mcgregor next
#  Output:- label = neutral, sentiment_score = 0.8410835862159729
#  Input:- govt procures 25000
#  Output:- label = neutral, sentiment_score = 0.8363686800003052
#  Input:- japan braces for tsu
#  Output:- label = neutral, sentiment_score = 0.6864115595817566
#  Input:- dhanlaxmi bank repor
#  Output:- label = positive, sentiment_score = 0.6492381691932678
#  Input:- record 8 18 crore in
#  Output:- label = neutral, sentiment_score = 0.8299496173858643
#  Input:- why global leaders n
#  Output:- label = neutral, sentiment_score = 0.7219996452331543
#  Input:- zomato hikes platfor
#  Output:- label = neutral, sentiment_score = 0.7743561863899231
#  Input:- bbcs the tourist ret
#  Output:- label = positive, sentiment_score = 0.7776830196380615
#  Input:- this trojan banking
#  Output:- label = negative, sentiment_score = 0.8377593755722046
#  Input:- printing date of man
#  Output:- label = neutral, sentiment_score = 0.9189210534095764
#  Input:- netflix amazon prime
#  Output:- label = neutral, sentiment_score = 0.8830015063285828
#  Input:- 2023 flashback 17 co
#  Output:- label = neutral, sentiment_score = 0.541591465473175
#  Input:- predictions for 2024
#  Output:- label = neutral, sentiment_score = 0.8768710494041443
#  Input:- assam cm himanta bis
#  Output:- label = neutral, sentiment_score = 0.7996259331703186
#  Input:- tata motors total do
#  Output:- label = neutral, sentiment_score = 0.7454833388328552
#  Input:- wonder cement announ
#  Output:- label = neutral, sentiment_score = 0.8840728402137756
#  Input:- indias steel sector
#  Output:- label = neutral, sentiment_score = 0.5769420266151428
#  Input:- flexible workspace p
#  Output:- label = neutral, sentiment_score = 0.622397243976593
#  Input:- three game of throne
#  Output:- label = neutral, sentiment_score = 0.9086427688598633
#  Input:- nearly 97 38 rs 2000
#  Output:- label = neutral, sentiment_score = 0.9157401919364929
#  Input:- world needs india to
#  Output:- label = neutral, sentiment_score = 0.6208035349845886
#  Input:- colorado mother susp
#  Output:- label = negative, sentiment_score = 0.7569795250892639
#  Input:- new year top 6 make
#  Output:- label = neutral, sentiment_score = 0.7917914986610413
#  Input:- fyllo in talks to pa
#  Output:- label = neutral, sentiment_score = 0.7745429277420044
#  Input:- japan earthquake vid
#  Output:- label = neutral, sentiment_score = 0.704947829246521
#  Input:- these apps can boost
#  Output:- label = positive, sentiment_score = 0.9542558193206787
#  Input:- high import duties r
#  Output:- label = neutral, sentiment_score = 0.6897906064987183
#  Input:- maruti suzuki total
#  Output:- label = neutral, sentiment_score = 0.7285814881324768
#  Input:- japan earthquakes an
#  Output:- label = neutral, sentiment_score = 0.5608425140380859
#  Input:- surfer dies after sh
#  Output:- label = negative, sentiment_score = 0.5941018462181091
#  Input:- gypsy rose blanchard
#  Output:- label = positive, sentiment_score = 0.8016365170478821
#  Input:- venture highway sell
#  Output:- label = neutral, sentiment_score = 0.9034122228622437
#  Input:- bajaj auto dec sales
#  Output:- label = neutral, sentiment_score = 0.7393590211868286
#  Input:- ek thi congress aaps
#  Output:- label = neutral, sentiment_score = 0.7393655776977539
#  Input:- denmarks queen margr
#  Output:- label = neutral, sentiment_score = 0.9252575635910034
#  Input:- active covid cases i
#  Output:- label = neutral, sentiment_score = 0.5901830792427063
#  Input:- mm total auto sales
#  Output:- label = neutral, sentiment_score = 0.8634588718414307
#  Input:- cheque bounce case c
#  Output:- label = neutral, sentiment_score = 0.6903666853904724
#  Input:- tech view nifty bull
#  Output:- label = neutral, sentiment_score = 0.7856413125991821
#  Input:- love you india how z
#  Output:- label = positive, sentiment_score = 0.959851861000061
#  Input:- nifty bank closes lo
#  Output:- label = neutral, sentiment_score = 0.7902592420578003
#  Input:- will thalapathy vija
#  Output:- label = neutral, sentiment_score = 0.8505460023880005
#  Input:- ongc seeks partners
#  Output:- label = neutral, sentiment_score = 0.785739004611969
#  Input:- air india a350 booki
#  Output:- label = neutral, sentiment_score = 0.7326273918151855
#  Input:- should one be extra
#  Output:- label = neutral, sentiment_score = 0.8534016609191895
#  Input:- gang rape of iit bhu
#  Output:- label = negative, sentiment_score = 0.5930832028388977
#  Input:- japan earthquakes wa
#  Output:- label = neutral, sentiment_score = 0.8601956367492676
#  Input:- new years day 2024 s
#  Output:- label = neutral, sentiment_score = 0.9250799417495728
#  Input:- 28811 complaints of
#  Output:- label = negative, sentiment_score = 0.6579901576042175
#  Input:- those who chose to b
#  Output:- label = negative, sentiment_score = 0.5729296207427979
#  Input:- gst collections indi
#  Output:- label = neutral, sentiment_score = 0.6714675426483154
#  Input:- sensex nifty close f
#  Output:- label = neutral, sentiment_score = 0.6323269605636597
#  Input:- multibagger bhel sha
#  Output:- label = neutral, sentiment_score = 0.7288556098937988
#  Input:- k drama actor cho ye
#  Output:- label = positive, sentiment_score = 0.735954999923706
#  Input:- bill clinton to be i
#  Output:- label = neutral, sentiment_score = 0.940081775188446
#  Input:- 2023 as india gasps
#  Output:- label = neutral, sentiment_score = 0.7777833342552185
#  Input:- ongc seeks partners
#  Output:- label = neutral, sentiment_score = 0.785739004611969
#  Input:- masood azhar kandhah
#  Output:- label = negative, sentiment_score = 0.7160660028457642
#  Input:- what were the hits m
#  Output:- label = neutral, sentiment_score = 0.8877926468849182
#  Input:- ram temple premises
#  Output:- label = neutral, sentiment_score = 0.7895565629005432
#  Input:- stop weaponising tec
#  Output:- label = negative, sentiment_score = 0.8123835921287537
#  Input:- esconet technologies
#  Output:- label = neutral, sentiment_score = 0.9238426089286804
#  Input:- what is going to be
#  Output:- label = neutral, sentiment_score = 0.9111911654472351
#  Input:- ive moved on from li
#  Output:- label = positive, sentiment_score = 0.5438998937606812
#  Input:- nifty overvalued by
#  Output:- label = neutral, sentiment_score = 0.690183699131012
#  Input:- covid sub variant jn
#  Output:- label = neutral, sentiment_score = 0.737479031085968
#  Input:- vibrant gujarat summ
#  Output:- label = positive, sentiment_score = 0.610933780670166
#  Input:- petrol diesel sales
#  Output:- label = negative, sentiment_score = 0.6018686294555664
#  Input:- atf price cut by 4 p
#  Output:- label = neutral, sentiment_score = 0.8207040429115295
#  Input:- esconet technologies
#  Output:- label = neutral, sentiment_score = 0.9238426089286804
#  Input:- quick commerce food
#  Output:- label = neutral, sentiment_score = 0.7207188606262207
#  Input:- india pakistan excha
#  Output:- label = neutral, sentiment_score = 0.9203290939331055
#  Input:- air india express fa
#  Output:- label = positive, sentiment_score = 0.5139445662498474
#  Input:- pharma two wheelers
#  Output:- label = positive, sentiment_score = 0.6747080683708191
#  Input:- adani hires global t
#  Output:- label = neutral, sentiment_score = 0.8358779549598694
#  Input:- 2024 leap year what
#  Output:- label = neutral, sentiment_score = 0.9235284924507141
#  Input:- japan tsunami what i
#  Output:- label = negative, sentiment_score = 0.8558824062347412
#  Input:- book some profit in
#  Output:- label = neutral, sentiment_score = 0.8438330292701721
#  Input:- reliance power to se
#  Output:- label = neutral, sentiment_score = 0.9260400533676147
#  Input:- another bizarre thef
#  Output:- label = negative, sentiment_score = 0.8766154050827026
#  Input:- buy dhanuka agritech
#  Output:- label = neutral, sentiment_score = 0.8917369842529297
#  Input:- fo stocks adani ente
#  Output:- label = neutral, sentiment_score = 0.8804617524147034
#  Input:- we would like to mai
#  Output:- label = neutral, sentiment_score = 0.6963229179382324
#  Input:- buy bayer cropscienc
#  Output:- label = neutral, sentiment_score = 0.8685856461524963
#  Input:- what will happen in
#  Output:- label = negative, sentiment_score = 0.5807262659072876
#  Input:- hero set to unveil 4
#  Output:- label = neutral, sentiment_score = 0.828723132610321
#  Input:- et explainer how com
#  Output:- label = neutral, sentiment_score = 0.8816123604774475
#  Input:- india starts four ye
#  Output:- label = neutral, sentiment_score = 0.9334947466850281
#  Input:- technical stock pick
#  Output:- label = neutral, sentiment_score = 0.9009625315666199
#  Input:- air india express ta
#  Output:- label = neutral, sentiment_score = 0.8777466416358948
#  Input:- railtel shares surge
#  Output:- label = neutral, sentiment_score = 0.788147509098053
#  Input:- horoscope prediction
#  Output:- label = positive, sentiment_score = 0.8764897584915161
#  Input:- bjps third straight
#  Output:- label = neutral, sentiment_score = 0.696885347366333
#  Input:- hfcl bags rs 1127 cr
#  Output:- label = neutral, sentiment_score = 0.8810363411903381
#  Input:- many themes that did
#  Output:- label = neutral, sentiment_score = 0.7097375392913818
#  Input:- how much can nifty g
#  Output:- label = neutral, sentiment_score = 0.7422460317611694
#  Input:- yes bank shares jump
#  Output:- label = positive, sentiment_score = 0.718802273273468
#  Input:- saudi fund outpaces
#  Output:- label = neutral, sentiment_score = 0.8018704652786255
#  Input:- new launches and sur
#  Output:- label = positive, sentiment_score = 0.8981332778930664
#  Input:- in memoriam from sat
#  Output:- label = neutral, sentiment_score = 0.857244610786438
#  Input:- ppc 2024 pariksha pe
#  Output:- label = neutral, sentiment_score = 0.8885406255722046
#  Input:- akshay kumar urges f
#  Output:- label = neutral, sentiment_score = 0.8462899327278137
#  Input:- 10 grams will there
#  Output:- label = positive, sentiment_score = 0.8019231557846069
#  Input:- four nostradamus pre
#  Output:- label = neutral, sentiment_score = 0.7895699143409729
#  Input:- stock markets off to
#  Output:- label = negative, sentiment_score = 0.6456839442253113
#  Input:- sameera agro shares
#  Output:- label = neutral, sentiment_score = 0.6189107298851013
#  Input:- why shimla saw the l
#  Output:- label = negative, sentiment_score = 0.6892877817153931
#  Input:- cows gold rings trea
#  Output:- label = neutral, sentiment_score = 0.9034791588783264
#  Input:- sensex nifty start 2
#  Output:- label = neutral, sentiment_score = 0.8089961409568787
#  Input:- sanjiv bhasin on why
#  Output:- label = neutral, sentiment_score = 0.8864470720291138
#  Input:- demand uptick easing
#  Output:- label = positive, sentiment_score = 0.5590298175811768
#  Input:- fundamental radar wh
#  Output:- label = neutral, sentiment_score = 0.7369781136512756
#  Input:- buy indian railway c
#  Output:- label = neutral, sentiment_score = 0.8561847805976868
#  Input:- buy ceat target pric
#  Output:- label = neutral, sentiment_score = 0.8496089577674866
#  Input:- happy new year 2024
#  Output:- label = positive, sentiment_score = 0.9477488994598389
#  Input:- buy itc target price
#  Output:- label = neutral, sentiment_score = 0.8239472508430481
#  Input:- for smartwatch brand
#  Output:- label = neutral, sentiment_score = 0.7890756726264954
#  Input:- planning to buy real
#  Output:- label = neutral, sentiment_score = 0.8121945261955261
#  Input:- celebs welcome new y
#  Output:- label = positive, sentiment_score = 0.9509620070457458
#  Input:- after partying hard
#  Output:- label = neutral, sentiment_score = 0.7772638201713562
#  Input:- senior manipur newsp
#  Output:- label = neutral, sentiment_score = 0.8669061660766602
#  Input:- stock radar 17 rally
#  Output:- label = positive, sentiment_score = 0.7091298699378967
#  Input:- manipur cm expresses
#  Output:- label = neutral, sentiment_score = 0.7141045331954956
#  Input:- china factory activi
#  Output:- label = negative, sentiment_score = 0.8739139437675476
#  Input:- hot stocks brokerage
#  Output:- label = neutral, sentiment_score = 0.9048298597335815
#  Input:- with attention to in
#  Output:- label = neutral, sentiment_score = 0.8866429924964905
#  Input:- fo stocks to buy tod
#  Output:- label = neutral, sentiment_score = 0.6711568832397461
#  Input:- bullion bull run to
#  Output:- label = positive, sentiment_score = 0.708225667476654
#  Input:- etmarkets fund manag
#  Output:- label = neutral, sentiment_score = 0.7940307259559631
#  Input:- etmarkets smart talk
#  Output:- label = neutral, sentiment_score = 0.6682363152503967
#  Input:- big movers on d stre
#  Output:- label = neutral, sentiment_score = 0.8851279616355896
#  Input:- fo ban list hindusta
#  Output:- label = neutral, sentiment_score = 0.5641024112701416
#  Input:- former thyrocare pro
#  Output:- label = neutral, sentiment_score = 0.8598052263259888
#  Input:- pre market action he
#  Output:- label = neutral, sentiment_score = 0.9452706575393677
#  Input:- skills ministry to u
#  Output:- label = neutral, sentiment_score = 0.8893806338310242
#  Input:- predictions for 2024
#  Output:- label = positive, sentiment_score = 0.6654598116874695
#  Input:- 10 top partners
#  Output:- label = positive, sentiment_score = 0.6615568995475769
#  Input:- stocks in news dr re
#  Output:- label = neutral, sentiment_score = 0.5053776502609253
#  Input:- 15 stocks across m c
#  Output:- label = neutral, sentiment_score = 0.8088096380233765
#  Input:- is the stock market
#  Output:- label = neutral, sentiment_score = 0.9195361137390137
#  Input:- new year new peaks d
#  Output:- label = neutral, sentiment_score = 0.8008285760879517
#  Input:- nifty 50 likely to c
#  Output:- label = positive, sentiment_score = 0.6684799194335938
#  Input:- predictions for 2024
#  Output:- label = neutral, sentiment_score = 0.7266795039176941
#  Input:- investment seen powe
#  Output:- label = positive, sentiment_score = 0.8520511388778687
#  Input:- geopolitical crises
#  Output:- label = negative, sentiment_score = 0.6402156352996826
#  Input:- why you shouldnt ove
#  Output:- label = neutral, sentiment_score = 0.7389720678329468
#  Input:- how can my daughter
#  Output:- label = neutral, sentiment_score = 0.828178346157074
#  Input:- a personal finance p
#  Output:- label = neutral, sentiment_score = 0.5121991634368896
#  Input:- 4 chemical sector st
#  Output:- label = positive, sentiment_score = 0.7996897101402283
#  Input:- achieving early fina
#  Output:- label = neutral, sentiment_score = 0.732246458530426
#  Input:- 7 whacky money finan
#  Output:- label = neutral, sentiment_score = 0.6347426176071167
#  Input:- motilal oswal flexi
#  Output:- label = neutral, sentiment_score = 0.6535724997520447
#  Input:- how to read interpre
#  Output:- label = neutral, sentiment_score = 0.8663496375083923
#  Input:- what are financial g
#  Output:- label = neutral, sentiment_score = 0.7429674863815308
#  Input:- how to make joint fi
#  Output:- label = neutral, sentiment_score = 0.8477632403373718
#  Input:- my new year money re
#  Output:- label = neutral, sentiment_score = 0.7511138916015625
#  Input:- govts shouldnt take
#  Output:- label = neutral, sentiment_score = 0.5802126526832581
#  Input:- ettech explainer nyt
#  Output:- label = neutral, sentiment_score = 0.7610360980033875
#  Input:- india job scene sees
#  Output:- label = neutral, sentiment_score = 0.5338016152381897
#  Input:- 2024 how the fintech
#  Output:- label = neutral, sentiment_score = 0.8166149854660034
#  Input:- isro to launch advan
#  Output:- label = neutral, sentiment_score = 0.7610037326812744
#  Input:- after a lacklustre 2
#  Output:- label = negative, sentiment_score = 0.5697287321090698
#  Input:- bond forwards set to
#  Output:- label = neutral, sentiment_score = 0.8168743848800659
#  Input:- revised standards br
#  Output:- label = neutral, sentiment_score = 0.764792263507843
#  Input:- virgin river season
#  Output:- label = neutral, sentiment_score = 0.8798779845237732
#  Input:- 2024 rose bowl parad
#  Output:- label = neutral, sentiment_score = 0.8576724529266357
#  Input:- quick commerce firms
#  Output:- label = neutral, sentiment_score = 0.839448094367981
#  Input:- waking up to the yea
#  Output:- label = neutral, sentiment_score = 0.8422085046768188
#  Input:- organisation buildin
#  Output:- label = positive, sentiment_score = 0.525916576385498
#  Input:- predictions for 2024
#  Output:- label = positive, sentiment_score = 0.5813391208648682
#  Input:- new bajaj chetak ele
#  Output:- label = neutral, sentiment_score = 0.8558728098869324
#  Input:- predictions for 2024
#  Output:- label = neutral, sentiment_score = 0.8158622980117798
#  Input:- stock picks of the w
#  Output:- label = positive, sentiment_score = 0.7618361711502075
#  Input:- mg motor india posts
#  Output:- label = positive, sentiment_score = 0.5461781620979309
#  Input:- at third meeting of
#  Output:- label = neutral, sentiment_score = 0.8832361102104187
#  Input:- buy sumitomo chemica
#  Output:- label = neutral, sentiment_score = 0.8712143898010254
#  Input:- happy leap year 2024
#  Output:- label = positive, sentiment_score = 0.9560873508453369
#  Input:- budget 2024 interim
#  Output:- label = positive, sentiment_score = 0.7460607886314392
#  Input:- how much of the 2023
#  Output:- label = neutral, sentiment_score = 0.9425272941589355
#  Input:- israel embassy blast
#  Output:- label = negative, sentiment_score = 0.6210153102874756
#  Input:- after setback in ass
#  Output:- label = neutral, sentiment_score = 0.8002866506576538
#  Input:- yeh fitness resoluti
#  Output:- label = neutral, sentiment_score = 0.7363669276237488
#  Input:- institutional invest
#  Output:- label = neutral, sentiment_score = 0.8507214784622192
#  Input:- cheap chinese ev res
#  Output:- label = neutral, sentiment_score = 0.6755469441413879
#  Input:- view more than repai
#  Output:- label = neutral, sentiment_score = 0.7696775794029236
#  Input:- india will be the gl
#  Output:- label = neutral, sentiment_score = 0.7872596383094788
#  Input:- predictions for 2024
#  Output:- label = positive, sentiment_score = 0.6453533172607422
#  Input:- top nifty50 stocks a
#  Output:- label = neutral, sentiment_score = 0.740056037902832
#  Input:- predictions for 2024
#  Output:- label = positive, sentiment_score = 0.8694616556167603
#  Input:- predictions for 2024
#  Output:- label = neutral, sentiment_score = 0.7109445929527283
#  Input:- disney dreamlight va
#  Output:- label = neutral, sentiment_score = 0.6666481494903564
#  Input:- smart fencing of 300
#  Output:- label = neutral, sentiment_score = 0.8013062477111816
#  Input:- coal indias supply t
#  Output:- label = neutral, sentiment_score = 0.8711984753608704
#  Input:- new movies on stream
#  Output:- label = neutral, sentiment_score = 0.7046473622322083
#  Input:- delhi bjp youth wing
#  Output:- label = neutral, sentiment_score = 0.6320629715919495
#  Input:- smelling old books
#  Output:- label = neutral, sentiment_score = 0.6469661593437195
#  Input:- nafed feels the puls
#  Output:- label = neutral, sentiment_score = 0.705403208732605
#  Input:- govt eases norms for
#  Output:- label = neutral, sentiment_score = 0.868459165096283
#  Input:- fci to borrow rs 500
#  Output:- label = neutral, sentiment_score = 0.8751539587974548
#  Input:- parties lok sabha po
#  Output:- label = neutral, sentiment_score = 0.7276492714881897
#  Input:- feefo fi fum smell t
#  Output:- label = neutral, sentiment_score = 0.7630743980407715
#  Input:- catherine zeta jones
#  Output:- label = positive, sentiment_score = 0.9371907711029053
#  Input:- sriram raghavan reve
#  Output:- label = neutral, sentiment_score = 0.7565320730209351
#  Input:- toni braxton and rap
#  Output:- label = neutral, sentiment_score = 0.7906983494758606
#  Input:- dont let bad climate
#  Output:- label = negative, sentiment_score = 0.7039237022399902
#  Input:- four manipur police
#  Output:- label = negative, sentiment_score = 0.6303853392601013
#  Input:- new ruling on benami
#  Output:- label = neutral, sentiment_score = 0.8964056372642517
#  Input:- blake sheltons new y
#  Output:- label = negative, sentiment_score = 0.652376651763916
#  Input:- 16th finance commiss
#  Output:- label = neutral, sentiment_score = 0.9151571989059448
#  Input:- india bloc meetings
#  Output:- label = neutral, sentiment_score = 0.9418304562568665
#  Input:- s jaishankar on why
#  Output:- label = neutral, sentiment_score = 0.7881426215171814
#  Input:- monster hunter now j
#  Output:- label = neutral, sentiment_score = 0.8464532494544983
#  Input:- manipur violence cbi
#  Output:- label = neutral, sentiment_score = 0.5369090437889099
#  Input:- bjp readies 2 month
#  Output:- label = neutral, sentiment_score = 0.7132102847099304
#  Input:- new shinobi game her
#  Output:- label = neutral, sentiment_score = 0.8317254185676575
#  Input:- good samaritans moll
#  Output:- label = neutral, sentiment_score = 0.5770812034606934
#  Input:- love island all star
#  Output:- label = neutral, sentiment_score = 0.6990932822227478
#  Input:- salesman and two boa
#  Output:- label = neutral, sentiment_score = 0.8822716474533081
#  Input:- why it would be a ch
#  Output:- label = neutral, sentiment_score = 0.6582762598991394
#  Input:- evo japan 2024 this
#  Output:- label = neutral, sentiment_score = 0.7916661500930786
#  Input:- marvels what if seas
#  Output:- label = neutral, sentiment_score = 0.8888537287712097
#  Input:- truckers protest mha
#  Output:- label = neutral, sentiment_score = 0.6594947576522827
#  Input:- jeffrey epstein cour
#  Output:- label = neutral, sentiment_score = 0.9341734051704407
#  Input:- noida admin asks pvt
#  Output:- label = neutral, sentiment_score = 0.653296947479248
#  Input:- jharkhand cm hemant
#  Output:- label = neutral, sentiment_score = 0.7085294723510742
#  Input:- dengue monkeypox abn
#  Output:- label = negative, sentiment_score = 0.8055816292762756
#  Input:- lic gets gst demand
#  Output:- label = neutral, sentiment_score = 0.8655405044555664
#  Input:- manipur violence mei
#  Output:- label = negative, sentiment_score = 0.497128963470459
#  Input:- wearables firm ultra
#  Output:- label = neutral, sentiment_score = 0.49743619561195374
#  Input:- customers complaints
#  Output:- label = negative, sentiment_score = 0.526641309261322
#  Input:- 151 fleeing myanmar
#  Output:- label = neutral, sentiment_score = 0.6459622383117676
#  Input:- world introvert day
#  Output:- label = negative, sentiment_score = 0.6921809911727905
#  Input:- taylor swift is attr
#  Output:- label = negative, sentiment_score = 0.7487491369247437
#  Input:- total upi transactio
#  Output:- label = neutral, sentiment_score = 0.6479315161705017
#  Input:- billy joel jokes tha
#  Output:- label = neutral, sentiment_score = 0.7245919108390808
#  Input:- ahead of market 10 t
#  Output:- label = neutral, sentiment_score = 0.9260458946228027
#  Input:- rbi grants payment a
#  Output:- label = neutral, sentiment_score = 0.8678799271583557
#  Input:- flipkart cofounder b
#  Output:- label = neutral, sentiment_score = 0.6748070120811462
#  Input:- lieutenant general r
#  Output:- label = neutral, sentiment_score = 0.948394775390625
#  Input:- nicki minaj grounds
#  Output:- label = negative, sentiment_score = 0.7513114809989929
#  Input:- good grief check out
#  Output:- label = negative, sentiment_score = 0.8541247844696045
#  Input:- manipur shootout rpf
#  Output:- label = negative, sentiment_score = 0.7282893657684326
#  Input:- oppenheimer when wil
#  Output:- label = neutral, sentiment_score = 0.9380205273628235
#  Input:- pakistan sends back
#  Output:- label = negative, sentiment_score = 0.8194108605384827
#  Input:- jyoti cnc automation
#  Output:- label = neutral, sentiment_score = 0.9202184081077576
#  Input:- sebi slaps rs 6 lakh
#  Output:- label = negative, sentiment_score = 0.6603191494941711
#  Input:- bjp accuses owaisi o
#  Output:- label = neutral, sentiment_score = 0.5429242849349976
#  Input:- mo salahs penalty wo
#  Output:- label = negative, sentiment_score = 0.7052648663520813
#  Input:- jeremy renner shares
#  Output:- label = neutral, sentiment_score = 0.8990024328231812
#  Input:- knives out 3 release
#  Output:- label = neutral, sentiment_score = 0.9084198474884033
#  Input:- review of bmi testin
#  Output:- label = neutral, sentiment_score = 0.903696596622467
#  Input:- india womens suffer
#  Output:- label = negative, sentiment_score = 0.7206479907035828
#  Input:- fuel supply hit due
#  Output:- label = negative, sentiment_score = 0.7604353427886963
#  Input:- indias record car sa
#  Output:- label = neutral, sentiment_score = 0.6708239316940308
#  Input:- asian paints gets gs
#  Output:- label = neutral, sentiment_score = 0.822096586227417
#  Input:- philanthropic titans
#  Output:- label = neutral, sentiment_score = 0.600143313407898
#  Input:- cci clears punjab st
#  Output:- label = neutral, sentiment_score = 0.8972893357276917
#  Input:- zendaya leads the co
#  Output:- label = neutral, sentiment_score = 0.6947757005691528
#  Input:- yvonne strahovski we
#  Output:- label = positive, sentiment_score = 0.8071290254592896
#  Input:- govt issues sop to m
#  Output:- label = neutral, sentiment_score = 0.593772292137146
#  Input:- several grapplers se
#  Output:- label = neutral, sentiment_score = 0.863310694694519
#  Input:- health minister mand
#  Output:- label = neutral, sentiment_score = 0.8647098541259766
#  Input:- a happy new year ind
#  Output:- label = positive, sentiment_score = 0.9704371094703674
#  Input:- will penalise states
#  Output:- label = negative, sentiment_score = 0.5279214978218079
#  Input:- congress raises rs 1
#  Output:- label = neutral, sentiment_score = 0.8665602207183838
#  Input:- how two gujarat coll
#  Output:- label = negative, sentiment_score = 0.5247440934181213
#  Input:- govt plans to end fr
#  Output:- label = neutral, sentiment_score = 0.819908857345581
#  Input:- declaration of divid
#  Output:- label = neutral, sentiment_score = 0.9094709157943726
#  Input:- monster 2023 online
#  Output:- label = neutral, sentiment_score = 0.9092702269554138
#  Input:- truck drivers strike
#  Output:- label = negative, sentiment_score = 0.8075054287910461
#  Input:- avenue supermarts q3
#  Output:- label = neutral, sentiment_score = 0.525535523891449
#  Input:- zomatos war room to
#  Output:- label = neutral, sentiment_score = 0.9009516835212708
#  Input:- radhakishan damani p
#  Output:- label = neutral, sentiment_score = 0.9004977941513062
#  Input:- canara bank to open
#  Output:- label = neutral, sentiment_score = 0.675129234790802
#  Input:- karnataka cm siddara
#  Output:- label = neutral, sentiment_score = 0.7684672474861145
#  Input:- current covid cases
#  Output:- label = neutral, sentiment_score = 0.743881344795227
#  Input:- muthoot finance to r
#  Output:- label = neutral, sentiment_score = 0.8187508583068848
#  Input:- gujarat hc says not
#  Output:- label = negative, sentiment_score = 0.5025214552879333
#  Input:- ipl auction 2024 set
#  Output:- label = positive, sentiment_score = 0.634319543838501
#  Input:- birlasoft appoints m
#  Output:- label = neutral, sentiment_score = 0.9195764660835266
#  Input:- joe biden stumbles r
#  Output:- label = neutral, sentiment_score = 0.6355273723602295
#  Input:- involvement of forei
#  Output:- label = negative, sentiment_score = 0.5608938336372375
#  Input:- knowledgehut chief s
#  Output:- label = neutral, sentiment_score = 0.6765754222869873
#  Input:- pm modi rolls out ne
#  Output:- label = neutral, sentiment_score = 0.7522870302200317
#  Input:- rakesh deshmukh step
#  Output:- label = neutral, sentiment_score = 0.8110672235488892
#  Input:- government disputes
#  Output:- label = neutral, sentiment_score = 0.5944736003875732
#  Input:- south koreas oppn le
#  Output:- label = neutral, sentiment_score = 0.8312016129493713
#  Input:- merger with congress
#  Output:- label = neutral, sentiment_score = 0.908481240272522
#  Input:- indian railways hous
#  Output:- label = negative, sentiment_score = 0.6376930475234985
#  Input:- tata pay bags paymen
#  Output:- label = neutral, sentiment_score = 0.8394584059715271
#  Input:- stars get lovey dove
#  Output:- label = positive, sentiment_score = 0.9671376943588257
#  Input:- army to be deployed
#  Output:- label = neutral, sentiment_score = 0.9279771447181702
#  Input:- congress seeks justi
#  Output:- label = neutral, sentiment_score = 0.5297607183456421
#  Input:- suzuki motorcycle in
#  Output:- label = neutral, sentiment_score = 0.7578474283218384
#  Input:- esports set to reach
#  Output:- label = positive, sentiment_score = 0.8389294147491455
#  Input:- with growing appetit
#  Output:- label = neutral, sentiment_score = 0.6906277537345886
#  Input:- rajasthan 2023 chang
#  Output:- label = neutral, sentiment_score = 0.8686169385910034
#  Input:- vanderpump villa tra
#  Output:- label = neutral, sentiment_score = 0.9041821956634521
#  Input:- inside the 2024 shop
#  Output:- label = neutral, sentiment_score = 0.7689610123634338
#  Input:- coal indias supply t
#  Output:- label = neutral, sentiment_score = 0.8257903456687927
#  Input:- kay cee energy and i
#  Output:- label = neutral, sentiment_score = 0.8898911476135254
#  Input:- jeffrey epsteins ex
#  Output:- label = neutral, sentiment_score = 0.7238593697547913
#  Input:- vraj iron and steel
#  Output:- label = neutral, sentiment_score = 0.9038809537887573
#  Input:- nhs gears up for rec
#  Output:- label = neutral, sentiment_score = 0.8164936304092407
#  Input:- aquaman 3 a watery f
#  Output:- label = neutral, sentiment_score = 0.8212248086929321
#  Input:- decoding us new rule
#  Output:- label = neutral, sentiment_score = 0.9091471433639526
#  Input:- etmarkets fund manag
#  Output:- label = neutral, sentiment_score = 0.8688921332359314
#  Input:- divine power energy
#  Output:- label = neutral, sentiment_score = 0.6080538630485535
#  Input:- speculations over jh
#  Output:- label = neutral, sentiment_score = 0.9602929949760437
#  Input:- kia appoints gwanggu
#  Output:- label = neutral, sentiment_score = 0.9024068713188171
#  Input:- india bangladesh tra
#  Output:- label = neutral, sentiment_score = 0.7192066311836243
#  Input:- rafael nadal makes s
#  Output:- label = positive, sentiment_score = 0.8706598281860352
#  Input:- congress prospects b
#  Output:- label = positive, sentiment_score = 0.696721076965332
#  Input:- tech view nifty cand
#  Output:- label = negative, sentiment_score = 0.5456928610801697
#  Input:- sound of freedom mov
#  Output:- label = neutral, sentiment_score = 0.7920176982879639
#  Input:- bcci seeks bids for
#  Output:- label = neutral, sentiment_score = 0.9184011220932007
#  Input:- bihar caste survey b
#  Output:- label = neutral, sentiment_score = 0.821685254573822
#  Input:- iit m looks to incub
#  Output:- label = neutral, sentiment_score = 0.5301291346549988
#  Input:- fmcg will continue t
#  Output:- label = neutral, sentiment_score = 0.7302060723304749
#  Input:- japan plane fire vir
#  Output:- label = negative, sentiment_score = 0.6544492244720459
#  Input:- jakson group install
#  Output:- label = neutral, sentiment_score = 0.9162173271179199
#  Input:- planning to visit ja
#  Output:- label = neutral, sentiment_score = 0.7366208434104919
#  Input:- powerball awards fir
#  Output:- label = positive, sentiment_score = 0.6840512752532959
#  Input:- ansa folding carton
#  Output:- label = neutral, sentiment_score = 0.8910646438598633
#  Input:- asba mechanism for s
#  Output:- label = negative, sentiment_score = 0.5048336982727051
#  Input:- canada may be losing
#  Output:- label = negative, sentiment_score = 0.6823366284370422
#  Input:- nicaragua flight pas
#  Output:- label = neutral, sentiment_score = 0.549910843372345
#  Input:- rays power infra fil
#  Output:- label = neutral, sentiment_score = 0.9263449907302856
#  Input:- sc issues notice to
#  Output:- label = neutral, sentiment_score = 0.821351170539856
#  Input:- tea production falls
#  Output:- label = neutral, sentiment_score = 0.6557303667068481
#  Input:- uk braces for heavy
#  Output:- label = neutral, sentiment_score = 0.7294822335243225
#  Input:- technical breakout s
#  Output:- label = neutral, sentiment_score = 0.890049397945404
#  Input:- why congress govt no
#  Output:- label = neutral, sentiment_score = 0.7001518607139587
#  Input:- powerball 842 millio
#  Output:- label = neutral, sentiment_score = 0.7566497325897217
#  Input:- 312 covid sub varian
#  Output:- label = neutral, sentiment_score = 0.5027394890785217
#  Input:- about 2000 petrol pu
#  Output:- label = negative, sentiment_score = 0.7662129998207092
#  Input:- army probing civilia
#  Output:- label = negative, sentiment_score = 0.7500764727592468
#  Input:- startups in 2024 inn
#  Output:- label = neutral, sentiment_score = 0.5652241110801697
#  Input:- indias coal output r
#  Output:- label = neutral, sentiment_score = 0.8300767540931702
#  Input:- furloughs to weigh o
#  Output:- label = neutral, sentiment_score = 0.880072832107544
#  Input:- union bank of india
#  Output:- label = negative, sentiment_score = 0.7930479049682617
#  Input:- salaar continues to
#  Output:- label = positive, sentiment_score = 0.6775839328765869
#  Input:- fire breaks out in p
#  Output:- label = neutral, sentiment_score = 0.5382974743843079
#  Input:- nifty bank falls nea
#  Output:- label = neutral, sentiment_score = 0.6113843321800232
#  Input:- everyone wants to do
#  Output:- label = neutral, sentiment_score = 0.7575621008872986
#  Input:- easy trip planners g
#  Output:- label = positive, sentiment_score = 0.5184097290039062
#  Input:- over 1 crore people
#  Output:- label = neutral, sentiment_score = 0.7673133611679077
#  Input:- bhel making india se
#  Output:- label = neutral, sentiment_score = 0.7608693838119507
#  Input:- govt lets women empl
#  Output:- label = neutral, sentiment_score = 0.847154438495636
#  Input:- goldman sachs cuts i
#  Output:- label = neutral, sentiment_score = 0.6699812412261963
#  Input:- ed i t cbi have been
#  Output:- label = neutral, sentiment_score = 0.8826794028282166
#  Input:- sensex nifty fall fo
#  Output:- label = negative, sentiment_score = 0.5993297100067139
#  Input:- backstreet boys aj m
#  Output:- label = neutral, sentiment_score = 0.7920655608177185
#  Input:- parliament breach ac
#  Output:- label = neutral, sentiment_score = 0.7997376918792725
#  Input:- hit and run laws tra
#  Output:- label = neutral, sentiment_score = 0.8970300555229187
#  Input:- kaushalya logistics
#  Output:- label = neutral, sentiment_score = 0.8789888620376587
#  Input:- hrh next services ip
#  Output:- label = neutral, sentiment_score = 0.9329953789710999
#  Input:- sensex falls 600 poi
#  Output:- label = negative, sentiment_score = 0.6214207410812378
#  Input:- four mistakes invest
#  Output:- label = neutral, sentiment_score = 0.4795796573162079
#  Input:- jeffrey epstein case
#  Output:- label = neutral, sentiment_score = 0.9146851897239685
#  Input:- lok sabha privileges
#  Output:- label = neutral, sentiment_score = 0.8285207748413086
#  Input:- indias oct dec sugar
#  Output:- label = neutral, sentiment_score = 0.7048805356025696
#  Input:- indias first all gir
#  Output:- label = neutral, sentiment_score = 0.9257497191429138
#  Input:- bitcoin hits 21 mont
#  Output:- label = neutral, sentiment_score = 0.7066624164581299
#  Input:- mpower presents et c
#  Output:- label = neutral, sentiment_score = 0.8378494381904602
#  Input:- ambani adani tata ji
#  Output:- label = positive, sentiment_score = 0.5221531987190247
#  Input:- y industry body
#  Output:- label = neutral, sentiment_score = 0.7378866672515869
#  Input:- truckers protest pan
#  Output:- label = negative, sentiment_score = 0.7159680128097534
#  Input:- ed conducts fresh se
#  Output:- label = neutral, sentiment_score = 0.711376965045929
#  Input:- pil in sc challenges
#  Output:- label = neutral, sentiment_score = 0.8039196133613586
#  Input:- five nations become
#  Output:- label = neutral, sentiment_score = 0.8768914341926575
#  Input:- engineering solution
#  Output:- label = neutral, sentiment_score = 0.8891646862030029
#  Input:- hair straightening c
#  Output:- label = negative, sentiment_score = 0.8230632543563843
#  Input:- gold prices likely t
#  Output:- label = neutral, sentiment_score = 0.9105798006057739
#  Input:- h 1b visa domestic r
#  Output:- label = neutral, sentiment_score = 0.7087188363075256
#  Input:- were expectations of
#  Output:- label = neutral, sentiment_score = 0.6524549722671509
#  Input:- gacl ties up with ve
#  Output:- label = neutral, sentiment_score = 0.6642913818359375
#  Input:- whatsapp users to so
#  Output:- label = negative, sentiment_score = 0.4966847598552704
#  Input:- how hiring and firin
#  Output:- label = neutral, sentiment_score = 0.9171401858329773
#  Input:- earn up to 7 5 fd in
#  Output:- label = neutral, sentiment_score = 0.8146246075630188
#  Input:- ipl indian premier l
#  Output:- label = neutral, sentiment_score = 0.8782811164855957
#  Input:- healthy investments
#  Output:- label = neutral, sentiment_score = 0.6592408418655396
#  Input:- ppfas mutual fund la
#  Output:- label = neutral, sentiment_score = 0.747485339641571
#  Input:- coal scam cbi closes
#  Output:- label = negative, sentiment_score = 0.6662991046905518
#  Input:- manipur firing incid
#  Output:- label = neutral, sentiment_score = 0.7937799692153931
#  Input:- bdr pharmaceuticals
#  Output:- label = neutral, sentiment_score = 0.885585606098175
#  Input:- ram temple inaugurat
#  Output:- label = negative, sentiment_score = 0.6879475712776184
#  Input:- tech rally in india
#  Output:- label = neutral, sentiment_score = 0.7454551458358765
#  Input:- ayodhya airport to b
#  Output:- label = neutral, sentiment_score = 0.9341439604759216
#  Input:- vodafone idea denies
#  Output:- label = neutral, sentiment_score = 0.700650155544281
#  Input:- feminine hygiene pen
#  Output:- label = neutral, sentiment_score = 0.6809832453727722
#  Input:- why have onion price
#  Output:- label = negative, sentiment_score = 0.9073915481567383
#  Input:- ayodhya 2 0 pm modi
#  Output:- label = neutral, sentiment_score = 0.7913663387298584
#  Input:- thailand cuts tax on
#  Output:- label = neutral, sentiment_score = 0.7339493036270142
#  Input:- ril acquires 9 of al
#  Output:- label = neutral, sentiment_score = 0.9009056091308594
#  Input:- geetika mehta from h
#  Output:- label = neutral, sentiment_score = 0.8295374512672424
#  Input:- food plazas shops fo
#  Output:- label = positive, sentiment_score = 0.5752731561660767
#  Input:- healthtech company q
#  Output:- label = neutral, sentiment_score = 0.8887554407119751
#  Input:- rays power infra ipo
#  Output:- label = neutral, sentiment_score = 0.9221210479736328
#  Input:- ctet 2024 on january
#  Output:- label = neutral, sentiment_score = 0.9504587054252625
#  Input:- india records 573 fr
#  Output:- label = neutral, sentiment_score = 0.5681121349334717
#  Input:- suspended sri lanka
#  Output:- label = neutral, sentiment_score = 0.6653371453285217
#  Input:- cbi closes 2019 ipl
#  Output:- label = negative, sentiment_score = 0.694083034992218
#  Input:- hershey names luigi
#  Output:- label = neutral, sentiment_score = 0.8697361946105957
#  Input:- thank your tarak ann
#  Output:- label = positive, sentiment_score = 0.8799259662628174
#  Input:- state of the art ayo
#  Output:- label = positive, sentiment_score = 0.6555027961730957
#  Input:- nithin kamath on zer
#  Output:- label = negative, sentiment_score = 0.6865105628967285
#  Input:- should you get into
#  Output:- label = neutral, sentiment_score = 0.9363976716995239
#  Input:- akanksha power ipo a
#  Output:- label = neutral, sentiment_score = 0.9299003481864929
#  Input:- quality matters in a
#  Output:- label = positive, sentiment_score = 0.7974201440811157
#  Input:- kia india names gwan
#  Output:- label = neutral, sentiment_score = 0.9252171516418457
#  Input:- truck driver protest
#  Output:- label = negative, sentiment_score = 0.6110614538192749
#  Input:- fo stocks bhel coal
#  Output:- label = neutral, sentiment_score = 0.8635042905807495
#  Input:- nifty to head toward
#  Output:- label = neutral, sentiment_score = 0.8166923522949219
#  Input:- fo stocks eicher mot
#  Output:- label = neutral, sentiment_score = 0.8952292799949646
#  Processing batch 2/553 (500 links)
# 🔹 Using 1 parallel threads...
#  Input:- et explainer how to
#  Output:- label = neutral, sentiment_score = 0.7710396647453308
#  Input:- mahareras action on
#  Output:- label = neutral, sentiment_score = 0.680139422416687
#  Input:- budget 2024 who will
#  Output:- label = neutral, sentiment_score = 0.9208663702011108
# ...
#  Input:- truckers call off st
#  Output:- label = neutral, sentiment_score = 0.7246677279472351
#  Input:- adanis data center j
#  Output:- label = neutral, sentiment_score = 0.9061312675476074
#  Input:- allcargo logistics p
#  Output:- label = neutral, sentiment_score = 0.6951544880867004
#  Input:- home secretary to me
#  Output:- label = neutral, sentiment_score = 0.8358692526817322
#  Input:- avenue supermarts sh
#  Output:- label = neutral, sentiment_score = 0.7396015524864197
#  Input:- truck drivers protes
#  Output:- label = negative, sentiment_score = 0.6654734015464783
#  Input:- indian army to provi
#  Output:- label = neutral, sentiment_score = 0.8715295791625977
#  Input:- adani stocks rally u
#  Output:- label = positive, sentiment_score = 0.6269803643226624
#  Input:- interim budget may b
#  Output:- label = neutral, sentiment_score = 0.8155210614204407
#  Input:- adani stocks in focu
#  Output:- label = neutral, sentiment_score = 0.8536630868911743
#  Input:- these 5 bank stocks
#  Output:- label = neutral, sentiment_score = 0.6098886728286743
#  Input:- adani hindenburg cas
#  Output:- label = neutral, sentiment_score = 0.637405276298523
#  Input:- mahua moitras ex all
#  Output:- label = neutral, sentiment_score = 0.7393693923950195
#  Input:- sbi home loan conces
#  Output:- label = neutral, sentiment_score = 0.7382202744483948
#  Input:- hit and run law driv
#  Output:- label = negative, sentiment_score = 0.5355581045150757
#  Input:- transforming the las
#  Output:- label = positive, sentiment_score = 0.5997512340545654
#  Input:- vro hospitality rais
#  Output:- label = positive, sentiment_score = 0.5098243355751038
#  Input:- fo stock strategy ho
#  Output:- label = neutral, sentiment_score = 0.8794203996658325
#  Input:- russia to send 200 o
#  Output:- label = neutral, sentiment_score = 0.8260455131530762
#  Input:- rpf recruitment noti
#  Output:- label = neutral, sentiment_score = 0.9098332524299622
#  Input:- vst industries share
#  Output:- label = neutral, sentiment_score = 0.8445619344711304
#  Input:- three arrested for r
#  Output:- label = negative, sentiment_score = 0.6718276143074036
#  Input:- gold rate today yell
#  Output:- label = neutral, sentiment_score = 0.5158932209014893
#  Input:- railways recruitment
#  Output:- label = neutral, sentiment_score = 0.9328781366348267
#  Input:- future proofing the
#  Output:- label = neutral, sentiment_score = 0.648038387298584
#  Input:- glenmark launches an
#  Output:- label = neutral, sentiment_score = 0.7988596558570862
#  Input:- adani hindenburg cas
#  Output:- label = neutral, sentiment_score = 0.8853163719177246
#  Input:- adani hindenburg row
#  Output:- label = neutral, sentiment_score = 0.8903112411499023
#  Input:- karan johar candidly
#  Output:- label = neutral, sentiment_score = 0.6968978047370911
#  Input:- india budget 2024 in
#  Output:- label = neutral, sentiment_score = 0.8559080958366394
#  Input:- smallcap multibagger
#  Output:- label = positive, sentiment_score = 0.738040030002594
#  Input:- take some chips off
#  Output:- label = neutral, sentiment_score = 0.8619068264961243
#  Input:- why are investors fl
#  Output:- label = neutral, sentiment_score = 0.6011294722557068
#  Input:- these 10 equity fund
#  Output:- label = neutral, sentiment_score = 0.5912918448448181
#  Input:- irans red sea power
#  Output:- label = negative, sentiment_score = 0.5662557482719421
#  Input:- buy shipping corpora
#  Output:- label = neutral, sentiment_score = 0.876400351524353
#  Input:- hrh next services de
#  Output:- label = neutral, sentiment_score = 0.9022728204727173
#  Input:- akanksha power and i
#  Output:- label = neutral, sentiment_score = 0.9106460213661194
#  Input:- delhi weather dense
#  Output:- label = negative, sentiment_score = 0.6643629670143127
#  Input:- rupee rises 4 paise
#  Output:- label = neutral, sentiment_score = 0.8434127569198608
#  Input:- sunil taldar named a
#  Output:- label = neutral, sentiment_score = 0.8317632675170898
#  Input:- buy coal india targe
#  Output:- label = neutral, sentiment_score = 0.8748340010643005
#  Input:- is volatility going
#  Output:- label = neutral, sentiment_score = 0.8900324106216431
#  Input:- france becomes first
#  Output:- label = neutral, sentiment_score = 0.8493717908859253
#  Input:- jsw steel bullish to
#  Output:- label = neutral, sentiment_score = 0.7770496010780334
#  Input:- a hotel stay may cos
#  Output:- label = negative, sentiment_score = 0.698550283908844
#  Input:- csr icon amitabh sha
#  Output:- label = neutral, sentiment_score = 0.6815445423126221
#  Input:- buy delhivery target
#  Output:- label = neutral, sentiment_score = 0.8870247602462769
#  Input:- indias manufacturing
#  Output:- label = neutral, sentiment_score = 0.762788712978363
#  Input:- shri balaji valve co
#  Output:- label = neutral, sentiment_score = 0.8977639675140381
#  Input:- new health insurance
#  Output:- label = neutral, sentiment_score = 0.9467481374740601
#  Input:- drivers protest what
#  Output:- label = negative, sentiment_score = 0.6752285957336426
#  Processing batch 3/553 (500 links)
# 🔹 Using 1 parallel threads...
#  Input:- fundamental radar wh
#  Output:- label = neutral, sentiment_score = 0.7322185039520264
#  Input:- sensex drops 200 poi
#  Output:- label = negative, sentiment_score = 0.7647333741188049
#  Input:- buy hero motocorp ta
#  Output:- label = neutral, sentiment_score = 0.8186219930648804
#  Input:- market is uptrending
#  Output:- label = neutral, sentiment_score = 0.6203402876853943
#  Input:- saving the panama ca
#  Output:- label = negative, sentiment_score = 0.8427212238311768
#  Input:- indian telcos have e
#  Output:- label = neutral, sentiment_score = 0.7467970252037048
#  Input:- fo stocks to buy tod
#  Output:- label = neutral, sentiment_score = 0.7436578273773193
#  Input:- alok industries jump
#  Output:- label = neutral, sentiment_score = 0.7456313967704773
#  Input:- actress ana ofelia m
#  Output:- label = neutral, sentiment_score = 0.8841898441314697
#  Input:- very positive on the
#  Output:- label = positive, sentiment_score = 0.9381220936775208
#  Input:- buy avenue supermart
#  Output:- label = neutral, sentiment_score = 0.8784768581390381
#  Input:- hot stocks brokerage
#  Output:- label = neutral, sentiment_score = 0.904661238193512
#  Input:- study finds cognitiv
#  Output:- label = neutral, sentiment_score = 0.6202487945556641
#  Input:- a pharma major and g
#  Output:- label = neutral, sentiment_score = 0.7892146706581116
#  Input:- softbank veteran nik
#  Output:- label = positive, sentiment_score = 0.7950505018234253
#  Input:- buy ashok leyland ta
#  Output:- label = neutral, sentiment_score = 0.8863492608070374
#  Input:- manoj ceramic shares
#  Output:- label = neutral, sentiment_score = 0.865478515625
#  Input:- buy mahindra amp mah
#  Output:- label = neutral, sentiment_score = 0.8384584784507751
#  Input:- budget 2024 bharat b
#  Output:- label = neutral, sentiment_score = 0.6382737159729004
#  Input:- ravi dharamshi on ho
#  Output:- label = neutral, sentiment_score = 0.6767054200172424
#  Input:- momentum pick multib
#  Output:- label = positive, sentiment_score = 0.5329708456993103
#  Input:- wait for results bef
#  Output:- label = neutral, sentiment_score = 0.8335393071174622
#  Input:- etmarkets smart talk
#  Output:- label = positive, sentiment_score = 0.7379859685897827
#  Input:- newlands old woes co
#  Output:- label = neutral, sentiment_score = 0.6707050800323486
#  Input:- sc to pronounce verd
#  Output:- label = neutral, sentiment_score = 0.9117227792739868
#  Input:- philippines stock ex
#  Output:- label = neutral, sentiment_score = 0.6501260995864868
#  Input:- fo ban list iex sail
#  Output:- label = negative, sentiment_score = 0.5552321672439575
#  Input:- researchers develop
#  Output:- label = neutral, sentiment_score = 0.6052457094192505
#  Input:- stock radar wipro hi
#  Output:- label = neutral, sentiment_score = 0.8463407754898071
#  Input:- stocks in news vst i
#  Output:- label = neutral, sentiment_score = 0.8601276278495789
#  Input:- fintechs top mutual
#  Output:- label = neutral, sentiment_score = 0.44340386986732483
#  Input:- pre market action he
#  Output:- label = neutral, sentiment_score = 0.9452706575393677
#  Input:- religare finvest iss
#  Output:- label = neutral, sentiment_score = 0.9374837279319763
#  Input:- ipo ring to get loud
#  Output:- label = neutral, sentiment_score = 0.5998254418373108
#  Input:- coal india can susta
#  Output:- label = positive, sentiment_score = 0.6094031929969788
#  Input:- it stares at slowest
#  Output:- label = negative, sentiment_score = 0.8227066993713379
#  Input:- catamaran president
#  Output:- label = negative, sentiment_score = 0.6215376853942871
#  Input:- nifty likely to move
#  Output:- label = neutral, sentiment_score = 0.6492356657981873
#  Input:- voda idea denies rep
#  Output:- label = neutral, sentiment_score = 0.6474002003669739
#  Input:- institutional invest
#  Output:- label = neutral, sentiment_score = 0.5540621280670166
#  Input:- radhakishan damani a
#  Output:- label = neutral, sentiment_score = 0.9171308279037476
#  Input:- sbi raises 1 billion
#  Output:- label = neutral, sentiment_score = 0.8027851581573486
#  Input:- vedanta resources bo
#  Output:- label = neutral, sentiment_score = 0.7487056851387024
#  Input:- dceu movies heres ho
#  Output:- label = neutral, sentiment_score = 0.9080838561058044
#  Input:- disney dreamlight va
#  Output:- label = positive, sentiment_score = 0.671271026134491
#  Input:- modern warfare 3 and
#  Output:- label = neutral, sentiment_score = 0.6936944127082825
#  Input:- genshin impact codes
#  Output:- label = neutral, sentiment_score = 0.7893753051757812
#  Input:- 90 day the single li
#  Output:- label = neutral, sentiment_score = 0.8315709829330444
#  Input:- 25 stocks hit fresh
#  Output:- label = positive, sentiment_score = 0.6559948921203613
#  Input:- canada announces new
#  Output:- label = neutral, sentiment_score = 0.846124529838562
#  Input:- gaza death toll pass
#  Output:- label = negative, sentiment_score = 0.7152719497680664
#  Input:- protests by truckers
#  Output:- label = neutral, sentiment_score = 0.5091674327850342
#  Input:- ig drones to survey
#  Output:- label = neutral, sentiment_score = 0.8878291845321655
#  Input:- top corporate bond f
#  Output:- label = neutral, sentiment_score = 0.7756023406982422
#  Input:- rajinikanth receives
#  Output:- label = neutral, sentiment_score = 0.7992668151855469
#  Input:- indonesia launches 5
#  Output:- label = neutral, sentiment_score = 0.8384349346160889
#  Input:- smbs to adopt stream
#  Output:- label = neutral, sentiment_score = 0.888624370098114
#  Input:- motorola brings on b
#  Output:- label = neutral, sentiment_score = 0.8709158301353455
#  Input:- mickey mouse takes d
#  Output:- label = neutral, sentiment_score = 0.9206523895263672
#  Input:- godrej properties bu
#  Output:- label = neutral, sentiment_score = 0.8831089735031128
#  Input:- hul gets gst notices
#  Output:- label = neutral, sentiment_score = 0.8752416372299194
#  Input:- three new criminal l
#  Output:- label = neutral, sentiment_score = 0.6012030839920044
#  Input:- us modifies eligibil
#  Output:- label = neutral, sentiment_score = 0.9032210111618042
#  Input:- transmission of rate
#  Output:- label = neutral, sentiment_score = 0.6558332443237305
#  Input:- govt may mandate vid
#  Output:- label = neutral, sentiment_score = 0.8925294876098633
#  Input:- bihar caste survey s
#  Output:- label = negative, sentiment_score = 0.5157949328422546
#  Input:- india bloc again see
#  Output:- label = neutral, sentiment_score = 0.9101863503456116
#  Input:- crypto prices today
#  Output:- label = neutral, sentiment_score = 0.9168721437454224
#  Input:- akasa air adds two b
#  Output:- label = neutral, sentiment_score = 0.8468121886253357
#  Input:- india inc faces onsl
#  Output:- label = neutral, sentiment_score = 0.7202569842338562
#  Input:- chakri lokapriya on
#  Output:- label = neutral, sentiment_score = 0.748150110244751
#  Input:- jee main exam candid
#  Output:- label = neutral, sentiment_score = 0.5734002590179443
#  Input:- plea filed in suprem
#  Output:- label = neutral, sentiment_score = 0.7888224124908447
#  Input:- rvnl shares rise ove
#  Output:- label = positive, sentiment_score = 0.5436934232711792
#  Input:- rbi revises declarat
#  Output:- label = neutral, sentiment_score = 0.6941127777099609
#  Input:- viral video zomato d
#  Output:- label = neutral, sentiment_score = 0.7557714581489563
#  Input:- experiencing a caree
#  Output:- label = neutral, sentiment_score = 0.8801358342170715
#  Input:- et graphics a look a
#  Output:- label = neutral, sentiment_score = 0.8619011640548706
#  Input:- omron expects sales
#  Output:- label = neutral, sentiment_score = 0.5293377637863159
#  Input:- saas platform kiko l
#  Output:- label = neutral, sentiment_score = 0.774314284324646
#  Input:- rbl sells 800 crore
#  Output:- label = neutral, sentiment_score = 0.6392217874526978
#  Input:- retailers say samsun
#  Output:- label = negative, sentiment_score = 0.6264715194702148
#  Input:- over 15 of medicines
#  Output:- label = negative, sentiment_score = 0.8884300589561462
#  Input:- hit and run cases tr
#  Output:- label = neutral, sentiment_score = 0.6458337306976318
#  Input:- torrent power plans
#  Output:- label = neutral, sentiment_score = 0.9035630822181702
#  Input:- storm henk wreaks ha
#  Output:- label = negative, sentiment_score = 0.8432517647743225
#  Input:- for congress india b
#  Output:- label = neutral, sentiment_score = 0.6474995017051697
#  Input:- weak rural demand se
#  Output:- label = negative, sentiment_score = 0.581650972366333
#  Input:- fortunes keep warzon
#  Output:- label = neutral, sentiment_score = 0.7742330431938171
#  Input:- navi mutual fund cha
#  Output:- label = neutral, sentiment_score = 0.9036063551902771
#  Input:- boi hikes rates for
#  Output:- label = neutral, sentiment_score = 0.8528227210044861
#  Input:- bjp forms panels to
#  Output:- label = neutral, sentiment_score = 0.9040713906288147
#  Input:- how diamond consumer
#  Output:- label = neutral, sentiment_score = 0.6912966966629028
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-4dbd6a7fbd34> in <cell line: 0>()
#       1 if __name__ == "__main__":
# ----> 2    sentiment_analysis_of_text_data()
#
# <ipython-input-29-bc43c9c43f94> in sentiment_analysis_of_text_data()
#      92         print(f"{Fore.YELLOW} Processing batch {i + 1}/{total_batches} ({len(batch_texts)} links){Style.RESET_ALL}")
#      93
# ---> 94         results = process_texts_in_parallel(batch_texts)  # Removed `[0]`
#      95         all_results.extend(results)
#      96
#
# <ipython-input-29-bc43c9c43f94> in process_texts_in_parallel(texts)
#      53
#      54     with ThreadPoolExecutor(NUM_PROCESSES) as executor:
# ---> 55         results = list(executor.map(find_sentiment, texts))
#      56
#      57     return results
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result_iterator()
#     617                     # Careful not to keep a reference to the popped future
#     618                     if timeout is None:
# --> 619                         yield _result_or_cancel(fs.pop())
#     620                     else:
#     621                         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# /usr/lib/python3.11/concurrent/futures/_base.py in _result_or_cancel(***failed resolving arguments***)
#     315     try:
#     316         try:
# --> 317             return fut.result(timeout)
#     318         finally:
#     319             fut.cancel()
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result(self, timeout)
#     449                     return self.__get_result()
#     450
# --> 451                 self._condition.wait(timeout)
#     452
#     453                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.11/threading.py in wait(self, timeout)
#     325         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326             if timeout is None:
# --> 327                 waiter.acquire()
#     328                 gotit = True
#     329             else:
#
# KeyboardInterrupt:
